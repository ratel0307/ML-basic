# %% [markdown]
# <a href="https://colab.research.google.com/github/ratel0307/ML-basic/blob/master/Ch01_3_%EC%9D%B4_%EB%8F%84%EC%84%9C%EA%B0%80_%EC%96%BC%EB%A7%88%EB%82%98_%EC%9D%B8%EA%B8%B0%EA%B0%80_%EC%A2%8B%EC%9D%84%EA%B9%8C%EC%9A%94%3F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !gdown https://drive.google.com/uc?id=1_SzXjrDa7PM38AHwkMcq8wywVtLGb01L
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1_SzXjrDa7PM38AHwkMcq8wywVtLGb01L
# To: /content/서울특별시교육청남산도서관 장서 대출목록 (2024년 02월).csv
# 100% 63.0M/63.0M [00:00<00:00, 79.5MB/s]

# %%
with open('서울특별시교육청남산도서관 장서 대출목록 (2024년 02월).csv') as f:
    print(f.readline())
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-3-c8d26564775f> in <cell line: 1>()
#       1 with open('서울특별시교육청남산도서관 장서 대출목록 (2024년 02월).csv') as f:
# ----> 2     print(f.readline())
#
# /usr/lib/python3.10/codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xb9 in position 0: invalid start byte

# %%
# open()함수는 텍스트파일이 UTF-8 형식으로 저장되어 있다고 가정함. 하지만 한글테스느는 여전히 EUC-KR을 사용하는 일이 잦음

# %%
import chardet
with open("서울특별시교육청남산도서관 장서 대출목록 (2024년 02월).csv", mode='rb') as f:
  d = f.readline()
print(chardet.detect(d))
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}

# %%
with open('서울특별시교육청남산도서관 장서 대출목록 (2024년 02월).csv', encoding='EUC-KR') as f:
  print(f.readline())
  print(f.readline())
  print(f.readline())
# Out:
# 번호,도서명,저자,출판사,발행년도,ISBN,세트 ISBN,부가기호,권,주제분류번호,도서권수,대출건수,등록일자,
#
# "1","노숙 인생","실뱅 테송 지음, 백선희 옮김","뮤진트리","2024","9791161111254","","","","","1","0","2024-02-29",
#
# "2","향문천의 한국어 비사","향문천 (지은이)","김영사","2024","9788934981015","","","","","1","0","2024-02-29",

# %% [markdown]
# csv 파일은 판다스 같은 도구로 읽는 것이 조금 더 편리함.

# %%
import pandas as pd
df = pd.read_csv('서울특별시교육청남산도서관 장서 대출목록 (2024년 02월).csv', encoding='EUC-KR')
# Out:
# <ipython-input-11-425e5213a654>:2: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('서울특별시교육청남산도서관 장서 대출목록 (2024년 02월).csv', encoding='EUC-KR')

# %%
df.head()
# Out:
#    번호               도서명                         저자     출판사  발행년도  \
# 0   1             노숙 인생           실뱅 테송 지음, 백선희 옮김    뮤진트리  2024
# 1   2       향문천의 한국어 비사                  향문천 (지은이)     김영사  2024
# 2   3    북으로 간 언어학자 김수경     이타가키 류타 지음, 고영진.임경화 옮김    푸른역사  2024
# 3   4        벨 훅스 같이 읽기         김동진 외 지음, 페페연구소 기획      동녘  2024
# 4   5  기꺼이 나의 죽음에 동의합니다  진 마모레오.조해나 슈넬러 지음, 김희정 옮김  위즈덤하우스  2024
#
#             ISBN  세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자  \
# 0  9791161111254      NaN  NaN  NaN    NaN     1     0  2024-02-29
# 1  9788934981015      NaN  NaN  NaN    NaN     1     0  2024-02-29
# 2  9791156122692      NaN  NaN  NaN    NaN     1     0  2024-02-29
# 3  9788972971146      NaN  NaN  NaN    NaN     1     0  2024-02-29
# 4  9791171711284      NaN  NaN  NaN    NaN     1     0  2024-02-29
#
#    Unnamed: 13
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
df.to_csv('ns_202402.csv')

# %%
with open('ns_202402.csv') as f:
  for i in range(3):
    print(f.readline(), end='')
# Out:
# ,번호,도서명,저자,출판사,발행년도,ISBN,세트 ISBN,부가기호,권,주제분류번호,도서권수,대출건수,등록일자,Unnamed: 13
# 0,1,노숙 인생,"실뱅 테송 지음, 백선희 옮김",뮤진트리,2024,9791161111254,,,,,1,0,2024-02-29,
# 1,2,향문천의 한국어 비사,향문천 (지은이),김영사,2024,9788934981015,,,,,1,0,2024-02-29,

# %%
ns_df = pd.read_csv('ns_202402.csv', index_col=0, low_memory=False)
ns_df.head()
# Out:
#    번호               도서명                         저자     출판사  발행년도  \
# 0   1             노숙 인생           실뱅 테송 지음, 백선희 옮김    뮤진트리  2024
# 1   2       향문천의 한국어 비사                  향문천 (지은이)     김영사  2024
# 2   3    북으로 간 언어학자 김수경     이타가키 류타 지음, 고영진.임경화 옮김    푸른역사  2024
# 3   4        벨 훅스 같이 읽기         김동진 외 지음, 페페연구소 기획      동녘  2024
# 4   5  기꺼이 나의 죽음에 동의합니다  진 마모레오.조해나 슈넬러 지음, 김희정 옮김  위즈덤하우스  2024
#
#             ISBN  세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자  \
# 0  9791161111254      NaN  NaN  NaN    NaN     1     0  2024-02-29
# 1  9788934981015      NaN  NaN  NaN    NaN     1     0  2024-02-29
# 2  9791156122692      NaN  NaN  NaN    NaN     1     0  2024-02-29
# 3  9788972971146      NaN  NaN  NaN    NaN     1     0  2024-02-29
# 4  9791171711284      NaN  NaN  NaN    NaN     1     0  2024-02-29
#
#    Unnamed: 13
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
