# %% [markdown]
# <a href="https://colab.research.google.com/github/ratel0307/ML-basic/blob/master/Ch02_1_API_%EC%82%AC%EC%9A%A9%ED%95%98%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  API(Application Programming Interface)란?
#
# > 두 프로그램이 서로 대화하기 위한 방법을 정의한 것
#
# 웹사이트는 웹 페이지를 서비스하기 위해 웹 서버 소트프웨어를 사용함. 이런 웹 서버 프로그램은 웹 브라우저와 통신할 때 HTTP라는 프로토콜을 사용함.
#
# HTTP(Hyper Text Transfer Protocol)란?
# > 인터넷에서 웹페이지를 전송하는 기본 통신방법임.
#
# 웹기반 API는 HTTP 프로토콜을 사용하지만, HTML을 주고받는 것이 아니라 일반적으로 CSV, JSON, XML 같은 파일을 사용함.
#
# JSON는 JavaScript Object Notation의 약자임. 파이썬의 딕셔너리와 유사.

# %%
d = {'name': '혼자 공부하는 데이터 분석'}
print(d['name'])
# Out:
# 혼자 공부하는 데이터 분석

# %%
import json

# %%
d_str = json.dumps(d, ensure_ascii=False)
print(d_str)
# Out:
# {"name": "혼자 공부하는 데이터 분석"}

# %%
print(type(d_str))
# Out:
# <class 'str'>

# %%
d2 = json.loads(d_str)
print(d2['name'])
# Out:
# 혼자 공부하는 데이터 분석

# %%
type(d2)
# Out:
# dict

# %%
d3 = json.loads('{"name": "공부하는 파이썬", "author": "박해선", "year": 2022}') #JSON: key, value에 항상 큰따음표 #' '로 감쌌으니 dict이 아니라 str임
print(d3['name'])
print(d3['author'])
print(d3['year'])
# Out:
# 공부하는 파이썬
# 박해선
# 2022

# %%
a = '{"name": "공부하는 파이썬", "author": "박해선", "year": 2022}'

# %%
type(a)
# Out:
# str

# %%
d4_str = """
[
  {"name": "혼자 공부하는 데이터 분석", "author": "박해선", "year": 2022},
  {"name": "혼자 공부하는 머신러닝+딥러닝", "author": "박해선", "year": 2020}
]
""" #새겹따옴표 사용하면 긴 문자율을 줄바꿈하여 입력할 수 있음
d4 = json.loads(d4_str)
print(d4[0]["author"])
# Out:
# 박해선

# %%
import pandas as pd
pd.read_json(d4_str)
# Out:
#                name author  year
# 0    혼자 공부하는 데이터 분석    박해선  2022
# 1  혼자 공부하는 머신러닝+딥러닝    박해선  2020

# %%
pd.DataFrame(d4)
# Out:
#                name author  year
# 0    혼자 공부하는 데이터 분석    박해선  2022
# 1  혼자 공부하는 머신러닝+딥러닝    박해선  2020

# %% [markdown]
# 파이썬에서 XML 데이터 다루기

# %%
x_str = """
<book>
  <name>혼자 공부하는 데이터 분석</name>
  <author>박해선</author>
  <year>2022</year>
</book>
"""

# %%
import xml.etree.ElementTree as et
book = et.fromstring(x_str)

# %%
print(type(book))
# Out:
# <class 'xml.etree.ElementTree.Element'>

# %%
print(book.tag) #부모 엘리먼트
# Out:
# book

# %%
book
# Out:
# <Element 'book' at 0x7d586c1731a0>

# %%
book_childs = list(book) #list로 변환할 때는 list()함수 사용
print(book_childs)
# Out:
# [<Element 'name' at 0x7d586c1731f0>, <Element 'author' at 0x7d586c173240>, <Element 'year' at 0x7d586c173290>]

# %%
name, author, year = book_childs
print(name.text)
print(author.text)
print(year.text)
# Out:
# 혼자 공부하는 데이터 분석
# 박해선
# 2022

# %%
name = book.findtext('name') #자식 엘리먼트

# %%
print(name)
# Out:
# 혼자 공부하는 데이터 분석

# %%
import requests

# %%
url = "http://data4library.kr/api/loanItemSrch?format=json&startDt=2024-01-01&endDt=2024-01-31&age=20&authKey=0535c02dbd7db34603132ff907b7189f3da0421a184decc091aac8c680804d74"

# %%
r = requests.get(url)

# %%
data = r.json()
print(data)
# Out:
# {'response': {'request': {'startDt': '2024-01-01', 'endDt': '2024-01-31', 'age': '20', 'pageNo': 1, 'pageSize': 200}, 'resultNum': 200, 'numFound': 5000, 'docs': [{'doc': {'no': 1, 'ranking': '1', 'bookname': '물고기는 존재하지 않는다 :상실, 사랑 그리고 숨어 있는 삶의 질서에 관한 이야기 ', 'authors': '룰루 밀러 지음 ;정지인 옮김', 'publisher': '곰출판', 'publication_year': '2021', 'isbn13': '9791189327156', 'addition_symbol': '03400', 'vol': '', 'class_no': '490.99', 'class_nm': '자연과학 > 동물학 > 동물학', 'loan_count': '707', 'bookImageURL': 'https://image.aladin.co.kr/product/28465/73/cover/k092835920_1.jpg', 'bookDtlUrl': 'https://data4library.kr/bookV?seq=6360937'}}, {'doc': {'no': 2, 'ranking': '2', 'bookname': '지구 끝의 온실 :김초엽 장편소설 ', 'authors': '지은이: 김초엽', 'publisher': 'Giant Books(자이언트북스)', 'publication_year': '2021', 'isbn13': '9791191824001', 'addition_symbol': '03810', 'vol': '', 'class_no': '813.7', 'class_nm': '문학 > 한국문학 > 소설', 'loan_count': '647', 'bookImageURL': 'https://image.aladin.co.kr/product/27692/63/cover/k082733434_
# ...

# %%
#API 승인요청중이여서 안 되는 중임...

# %%
# API가 뭔지 잘 설명해주는 동영상 찾아봄

# %%
#https://www.youtube.com/watch?v=ckSdPNKM2pY&t=11s

# %%
#https://www.youtube.com/watch?v=iyFHfzCRHA8
#https://www.youtube.com/watch?v=Jg3FFBLyhK0

# %%
data
# Out:
# {'response': {'request': {'startDt': '2024-01-01',
#    'endDt': '2024-01-31',
#    'age': '20',
#    'pageNo': 1,
#    'pageSize': 200},
#   'resultNum': 200,
#   'numFound': 5000,
#   'docs': [{'doc': {'no': 1,
#      'ranking': '1',
#      'bookname': '물고기는 존재하지 않는다 :상실, 사랑 그리고 숨어 있는 삶의 질서에 관한 이야기 ',
#      'authors': '룰루 밀러 지음 ;정지인 옮김',
#      'publisher': '곰출판',
#      'publication_year': '2021',
#      'isbn13': '9791189327156',
#      'addition_symbol': '03400',
#      'vol': '',
#      'class_no': '490.99',
#      'class_nm': '자연과학 > 동물학 > 동물학',
#      'loan_count': '707',
#      'bookImageURL': 'https://image.aladin.co.kr/product/28465/73/cover/k092835920_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6360937'}},
#    {'doc': {'no': 2,
#      'ranking': '2',
#      'bookname': '지구 끝의 온실 :김초엽 장편소설 ',
#      'authors': '지은이: 김초엽',
#      'publisher': 'Giant Books(자이언트북스)',
#      'publication_year': '2021',
#      'isbn13': '9791191824001',
# ...

# %%
books = []
for d in data['response']['docs']:
  books.append(d['doc'])

# %%
books
# Out:
# [{'no': 1,
#   'ranking': '1',
#   'bookname': '물고기는 존재하지 않는다 :상실, 사랑 그리고 숨어 있는 삶의 질서에 관한 이야기 ',
#   'authors': '룰루 밀러 지음 ;정지인 옮김',
#   'publisher': '곰출판',
#   'publication_year': '2021',
#   'isbn13': '9791189327156',
#   'addition_symbol': '03400',
#   'vol': '',
#   'class_no': '490.99',
#   'class_nm': '자연과학 > 동물학 > 동물학',
#   'loan_count': '707',
#   'bookImageURL': 'https://image.aladin.co.kr/product/28465/73/cover/k092835920_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6360937'},
#  {'no': 2,
#   'ranking': '2',
#   'bookname': '지구 끝의 온실 :김초엽 장편소설 ',
#   'authors': '지은이: 김초엽',
#   'publisher': 'Giant Books(자이언트북스)',
#   'publication_year': '2021',
#   'isbn13': '9791191824001',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '647',
#   'bookImageURL': 'https://image.aladin.co.kr/product/27692/63/cover/k082733434_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6065686'},
# ...

# %%
books_df = pd.DataFrame(books)
books_df #오...물고기는 존재하지 않는다가 1등이네? 빌린 순서대로 알려주는군
# Out:
#       no ranking                                        bookname  \
# 0      1       1  물고기는 존재하지 않는다 :상실, 사랑 그리고 숨어 있는 삶의 질서에 관한 이야기
# 1      2       2                             지구 끝의 온실 :김초엽 장편소설
# 2      3       3                              불편한 편의점 :김호연 장편소설
# 3      4       4                     우리가 빛의 속도로 갈 수 없다면 :김초엽 소설
# 4      5       5                              천 개의 파랑 :천선란 장편소설
# ..   ...     ...                                             ...
# 195  196     195                                    이어령의 마지막 수업
# 196  197     195                     GV 빌런 고태경 :2020 한경신춘문예 당선작
# 197  198     195                         새 마음으로 :이슬아의 이웃 어른 인터뷰
# 198  199     199       스파이와 배신자 : 역사상 가장 중요한 이중 스파이, 올레크 고르디옙스키
# 199  200     199                                참을 수 없는 존재의 가벼움
#
#                 authors            publisher publication_year         isbn13  \
# 0      룰루 밀러 지음 ;정지인 옮김                  곰출판             2021  9791189327156
# ...

# %%
books_df.to_json('20s_best_book.json')
